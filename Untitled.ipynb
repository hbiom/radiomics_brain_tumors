# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import random

from scipy import interp
from sklearn import svm
from sklearn.metrics import roc_curve, auc, confusion_matrix, roc_auc_score
from sklearn.model_selection import StratifiedShuffleSplit, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %matplotlib inline
plt.rcParams.update({'figure.max_open_warning': 0})
sns.set()
random.seed(30)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7355220da107> in <module>
#       7
#       8 from scipy import interp
# ----> 9 from sklearn import svm
#      10 from sklearn.metrics import roc_curve, auc, confusion_matrix, roc_auc_score
#      11 from sklearn.model_selection import StratifiedShuffleSplit, StratifiedKFold
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
data_path = "/home/hugo/code/radiomics_brain/radiomic_variable.csv"
df = pd.read_excel(data_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e13be6078406> in <module>
#       1 data_path = "/home/hugo/code/radiomics_brain/radiomic_variable.csv"
# ----> 2 df = pd.read_excel(data_path)
#
# NameError: name 'pd' is not defined
